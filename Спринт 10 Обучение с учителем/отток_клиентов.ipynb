# %% [markdown]
# <font size=4> Добрый день, Денис! Меня зовут Алан Созанов, будем обмениваться с тобой опытом для успешного прохождения задания! Если не против, предлагаю общаться на ты (иначе дай знать, и перейдем на «вы»). Свои рекомендации буду оформлять в виде комментариев в Markdown ячейках:<br><strong>
#     <li> <font color='red'> «красный цвет» </font> – важно исправить или внести пояснения
#     <li> <font color='orange'> «желтый цвет» </font>  – учесть, но можно не исправлять
#     <li> <font color='green'> «зеленый цвет» </font> – все отлично, плюс альтернативные пути решения задачи
#         </strong>
# <br> Прошу при внесении правок мои комментарии не удалять, а свои писать в соседних ячейках и выделять удобным цветом. Так коммуникация будет проходить эффективнее 👍.<br>
# </font>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Подключим-необходимые-модули-и-библиотеки-Python,-а-также-создадим-константы." data-toc-modified-id="Подключим-необходимые-модули-и-библиотеки-Python,-а-также-создадим-константы.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Подключим необходимые модули и библиотеки Python, а также создадим константы.</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предварительный-осмотр-данных" data-toc-modified-id="Предварительный-осмотр-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предварительный осмотр данных</a></span></li><li><span><a href="#Устранение-пропусков" data-toc-modified-id="Устранение-пропусков-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Устранение пропусков</a></span></li><li><span><a href="#Удаление-столбцов-не-несущих-информации" data-toc-modified-id="Удаление-столбцов-не-несущих-информации-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Удаление столбцов не несущих информации</a></span></li><li><span><a href="#Устранение-корреляции-между-признаками" data-toc-modified-id="Устранение-корреляции-между-признаками-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Устранение корреляции между признаками</a></span></li><li><span><a href="#Кодирование-строковых-признаков" data-toc-modified-id="Кодирование-строковых-признаков-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Кодирование строковых признаков</a></span></li><li><span><a href="#Проверка-целевого-признака-на-дисбаланс-классов" data-toc-modified-id="Проверка-целевого-признака-на-дисбаланс-классов-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Проверка целевого признака на дисбаланс классов</a></span></li></ul></li><li><span><a href="#Исследование-задачи-(получение-лучшего-результата,-без-учёта-дисбаланса-классов)" data-toc-modified-id="Исследование-задачи-(получение-лучшего-результата,-без-учёта-дисбаланса-классов)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи (получение лучшего результата, без учёта дисбаланса классов)</a></span><ul class="toc-item"><li><span><a href="#Разбиение-данных-на-обучающую,-валидационную-и-тестовую-выборки" data-toc-modified-id="Разбиение-данных-на-обучающую,-валидационную-и-тестовую-выборки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Разбиение данных на обучающую, валидационную и тестовую выборки</a></span></li><li><span><a href="#Получение-оптимальной-модели-без-учёта-дисбаланса-классов" data-toc-modified-id="Получение-оптимальной-модели-без-учёта-дисбаланса-классов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Получение оптимальной модели без учёта дисбаланса классов</a></span><ul class="toc-item"><li><span><a href="#Модель-классификации-деревом-решений" data-toc-modified-id="Модель-классификации-деревом-решений-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Модель классификации деревом решений</a></span></li><li><span><a href="#Модель-классификации-случайный-лес" data-toc-modified-id="Модель-классификации-случайный-лес-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Модель классификации случайный лес</a></span></li><li><span><a href="#Модель-классификации-логистическая-регрессия" data-toc-modified-id="Модель-классификации-логистическая-регрессия-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Модель классификации логистическая регрессия</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Пример-борьбы-с-дисбалансом-классов,-при-помощи-параметра-модели" data-toc-modified-id="Пример-борьбы-с-дисбалансом-классов,-при-помощи-параметра-модели-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Пример борьбы с дисбалансом классов, при помощи параметра модели</a></span><ul class="toc-item"><li><span><a href="#Модель-классификации-деревом-решений" data-toc-modified-id="Модель-классификации-деревом-решений-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Модель классификации деревом решений</a></span></li><li><span><a href="#Модель-классификации-случайный-лес" data-toc-modified-id="Модель-классификации-случайный-лес-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Модель классификации случайный лес</a></span></li><li><span><a href="#Модель-классификации-логистическая-регрессия" data-toc-modified-id="Модель-классификации-логистическая-регрессия-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Модель классификации логистическая регрессия</a></span></li></ul></li><li><span><a href="#Устранение-дисбаланса-в-данных" data-toc-modified-id="Устранение-дисбаланса-в-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Устранение дисбаланса в данных</a></span></li><li><span><a href="#Стандартизация-данных" data-toc-modified-id="Стандартизация-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Стандартизация данных</a></span></li><li><span><a href="#Получение-оптимальной-модели-при-устранённом-дисбалансе-классов" data-toc-modified-id="Получение-оптимальной-модели-при-устранённом-дисбалансе-классов-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Получение оптимальной модели при устранённом дисбалансе классов</a></span><ul class="toc-item"><li><span><a href="#Модель-классификации-деревом-решений" data-toc-modified-id="Модель-классификации-деревом-решений-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Модель классификации деревом решений</a></span></li><li><span><a href="#Модель-классификации-случайный-лес" data-toc-modified-id="Модель-классификации-случайный-лес-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Модель классификации случайный лес</a></span></li><li><span><a href="#Модель-классификации-логистическая-регрессия" data-toc-modified-id="Модель-классификации-логистическая-регрессия-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Модель классификации логистическая регрессия</a></span></li></ul></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Дообучение-лучших-моделей-по-объединённой-обучающей-и-валидационной-выборкам." data-toc-modified-id="Дообучение-лучших-моделей-по-объединённой-обучающей-и-валидационной-выборкам.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Дообучение лучших моделей по объединённой обучающей и валидационной выборкам.</a></span></li><li><span><a href="#Итоговое-тестирование-лучшей-модели" data-toc-modified-id="Итоговое-тестирование-лучшей-модели-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Итоговое тестирование лучшей модели</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# <div class='alert alert-success'> ✔️Хорошо, что сформулировал описание проекта, это помогает не забыть цели и особенности задачи.
# </div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Подключим необходимые модули и библиотеки Python, а также создадим константы.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from tqdm import tqdm
import matplotlib.pyplot as plt

# Константа псевдослучайности для алгоритмов обучения
RANDOM = 1111

# %% [markdown]
# ### Загрузка данных
# Данные предоставлены в виде csv-файла.

# %%
churn = pd.read_csv('/datasets/Churn.csv')

# %% [markdown]
# ### Предварительный осмотр данных
# - Посмотрим первые 5 строк таблицы,
# - Основные статистики количественных переменных,
# - Сводную информацию от таблице.

# %%
print('*'*100,'\nПервые десять строк таблицы.')
display(churn.head())
print('*'*100,'\nОсновные статистики количественных переменных.')
display(churn.describe())
print('*'*100,'\nСводная информация о таблице.')
display(churn.info())
# Out:
# ****************************************************************************************************
# Первые десять строк таблицы.
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
# ...

# %% [markdown]
# Данные предоставлены в 14 столбцах:
# - `RowNumber` — индекс строки в данных,
# - `CustomerId` — уникальный идентификатор клиента,
# - `Surname` — фамилия,
# - `CreditScore` — кредитный рейтинг,
# - `Geography` — страна проживания,
# - `Gender` — пол,
# - `Age` — возраст,
# - `Tenure` — сколько лет человек является клиентом банка,
# - `Balance` — баланс на счёте,
# - `NumOfProducts` — количество продуктов банка, используемых клиентом,
# - `HasCrCard` — наличие кредитной карты,
# - `IsActiveMember` — активность клиента,
# - `EstimatedSalary` — предполагаемая зарплата,
# - `Exited` — факт ухода клиента.
#
# Данные в таблице предоставлены типами float64, int64, object.
#
# Присутствуют пропуски в столбце `Tenure`, можно предположить, что это новые клиенты, проверим в дальнейшем, что по ним нет истории в банке.
#
# Статистики по количественным переменным выглядят правдоподобно, за исключением минимума `EstimatedSalary` равного 11.58.

# %% [markdown]
# <div class='alert alert-success'> ✔️Первичный анализ успешно завершен, намечена тактика дальнейших действий. Отмечу, что для отображения 10 первых строк, как писалось в функции достаточно это количество передать в метод head.
# </div>

# %% [markdown]
# ### Устранение пропусков
# Посмотрим на значение признаков для строк с пропуском в `Tenure`.

# %%
churn[~(churn['Tenure'] >= 0)].head(10)
# Out:
#      RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 30          31    15589475    Azikiwe          591     Spain  Female   39
# 48          49    15766205        Yin          550   Germany    Male   38
# 51          52    15768193  Trevisani          585   Germany    Male   36
# 53          54    15702298   Parkhill          655   Germany    Male   41
# 60          61    15651280     Hunter          742   Germany    Male   35
# 82          83    15641732      Mills          543    France  Female   36
# 85          86    15805254    Ndukaku          652     Spain  Female   75
# 94          95    15676966      Capon          730     Spain    Male   42
# 99         100    15633059    Fanucci          413    France    Male   34
# 111        112    15665790   Rowntree          538   Germany    Male   39
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 30      NaN       0.00              3          1               0
# ...

# %% [markdown]
# Как видно, пропуски не связаны с тем, что клиент не работал с данным банком (имеются не нулевые балансы, карты и т.п.).
# Так как количество лет работы с банком, является важным признаком при обучении, удалим строки с пропусками.

# %%
# удаление строк с пропусками
churn = churn.dropna()

# удаление столбца дало худший вариант, чем удаление строк с пропусками
#churn = churn.drop(columns='Tenure')

# замена на медиану дала худший вариант, чем удаление строк с пропусками
#churn.Tenure = churn.Tenure.fillna(churn.Tenure.median())

# %% [markdown]
# <div class='alert alert-success'> ✔️Можно и так.
# </div>

# %% [markdown]
# ### Удаление столбцов не несущих информации
# Следующие столбцы не несут полезной информации для прогнозирования результата:
# - `RowNumber` — индекс строки в данных,
# - `CustomerId` — уникальный идентификатор клиента,
# - `Surname` — фамилия.
# Удалим их из таблицы.

# %%
churn = churn.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# %% [markdown]
# <div class='alert alert-success'> ✔️Логично.
# </div>

# %% [markdown]
# ### Устранение корреляции между признаками

# %%
sns.pairplot(data=churn, hue='Exited')

# %% [markdown]
# Явно выраженной корреляции между признаками не наблюдается.

# %% [markdown]
# ### Кодирование строковых признаков
# Произведём кодирование строковых признаков методом прямого кодирования с удалением первого столбца, для исключения связанных признаков.

# %%
churn = pd.get_dummies(churn, drop_first=True)

# %% [markdown]
# <div class='alert alert-success'> ✔️Отлично, что используешь параметр  drop_first=True, который позволяет избавиться от фиктивных признаков.
#
#
#
# </div>

# %% [markdown]
# ### Проверка целевого признака на дисбаланс классов
# Оценим долю классов в столбце `Exited`.

# %%
print(f'Количество оставшихся клиентов (класс "0"): {(churn.Exited == 0).sum()}\n'
      f'Количество ушедших клиентов (класс "1"): {(churn.Exited == 1).sum()}\n'
      f'Доля ушедших клиентов: {(churn.Exited == 1).sum() / len(churn.Exited):.2f}')
# Out:
# Количество оставшихся клиентов (класс "0"): 7237
# Количество ушедших клиентов (класс "1"): 1854
# Доля ушедших клиентов: 0.20

# %% [markdown]
# <div class='alert alert-success'> ✔️Хорошо, дисбаланс установлен. Рекомендация не использовать count для подсчета общего числа значений, так как метод не учитывает nan-ы (https://zen.yandex.ru/media/id/5ee6f73b7cadb75a66e4c7e3/osnovnye-agregiruiuscie-funkcii-v-pandas-626f90e70c696a5e773dce4f).
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Спасибо за замечание. Заменил count на len().
#
# </div>

# %% [markdown]
# ## Исследование задачи (получение лучшего результата, без учёта дисбаланса классов)

# %% [markdown]
# ### Разбиение данных на обучающую, валидационную и тестовую выборки

# %% [markdown]
# В проекте будет применено обучение с учителемм, для этого выделим признаки `features` и целовой признак `target`.

# %%
features = churn.drop(columns='Exited')
target = churn.Exited

# %% [markdown]
# Разобьём исходные данные на 3 выбоки в соотношении 3:1:1 (обучающую, валидационну и тестовую соответственно).

# %%
# выделим обучающую выборку включающую в себя 60 % данных
features_train, features_valid_test, target_train, target_valid_test = train_test_split(
    features, target, train_size=0.6, stratify=target, random_state=RANDOM)

# оставшуюся часть разделим пополам на валидационную и тестовую выборки
features_valid, features_test, target_valid, target_test = train_test_split(
    features_valid_test, target_valid_test, test_size=0.5, stratify=target_valid_test, random_state=RANDOM)

# %% [markdown]
# <div class='alert alert-success'> ✔️Корректное деление! Рекомендую, если знаешь о несбалансированности классов делить датасет, используя параметр stratify, чтобы попытаться обеспечить соблюдение баланса.(https://zen.yandex.ru/media/id/5ee6f73b7cadb75a66e4c7e3/sozdanie-vyborok-v-usloviiah-disbalansa-klassov-625654c41dd29a5c65819c90)
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Спасибо за замечание. Применил параметр stratify. Итоговое значение F1-меры возросло с 0.60 до 0.62.
#
# </div>

# %%
print('Размер обучающих признаков:', features_train.shape)
print('Размер целевых признаков:', target_train.shape)
print('Размер валидационных признаков:', features_valid.shape)
print('Размер целевых признаков валидации:', target_valid.shape)
print('Размер тестовых признаков:', features_test.shape)
print('Размер целевых признаков теста:', target_test.shape)
# Out:
# Размер обучающих признаков: (5454, 11)
# Размер целевых признаков: (5454,)
# Размер валидационных признаков: (1818, 11)
# Размер целевых признаков валидации: (1818,)
# Размер тестовых признаков: (1819, 11)
# Размер целевых признаков теста: (1819,)

# %% [markdown]
# ### Получение оптимальной модели без учёта дисбаланса классов

# %% [markdown]
# #### Модель классификации деревом решений

# %% [markdown]
# Определим лучшую модель в зависимости от гиперпараметра `max_depth` перебором в цикле и оценке по валидационной выборке на F1-мере.

# %%
best_model_tree = None
best_score_f1_tree = 0

for depth in tqdm(range(1, 11)):
    model = DecisionTreeClassifier(random_state=RANDOM, max_depth=depth)
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    score = f1_score(target_valid, predicted_valid)
    if score > best_score_f1_tree:
        best_model_tree = model
        best_score_f1_tree = score

print(f'Лучшая модель решающего дерева: {best_model_tree}\n'
      f'F1-мера: {best_score_f1_tree}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_tree.predict_proba(features_valid)[:,1])}')
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 39.60it/s]
# Лучшая модель решающего дерева: DecisionTreeClassifier(max_depth=7, random_state=1111)
# F1-мера: 0.5647425897035881
# AUC-ROC: 0.820798491907227

# %% [markdown]
# <div class='alert alert-success'> ✔️Отлично, посмотрели параметры дерева и использовали индикатор прогресса.
# </div>

# %% [markdown]
# #### Модель классификации случайный лес

# %% [markdown]
# Определим лучшую модель в зависимости от гиперпараметра `n_estimators` перебором в цикле и оценке по валидационной выборке на F1-мере, параметр `max_depth` примем равным 7, как оптимальный для решающего дерева.

# %%
best_model_forest = None
best_score_f1_forest = 0

for est in tqdm(range(1, 100, 2)):
    model = RandomForestClassifier(random_state=RANDOM, n_estimators=est, max_depth=7)
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    score = f1_score(target_valid, predicted_valid)
    if score > best_score_f1_forest:
        best_model_forest = model
        best_score_f1_forest = score

print(f'Лучшая модель случайного леса: {best_model_forest}\n'
      f'F1-мера: {best_score_f1_forest}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_forest.predict_proba(features_valid)[:,1])}')
# Out:
# 100%|██████████| 50/50 [00:17<00:00,  2.91it/s]
# Лучшая модель случайного леса: RandomForestClassifier(max_depth=7, n_estimators=99, random_state=1111)
# F1-мера: 0.5355191256830601
# AUC-ROC: 0.8600599437073079

# %% [markdown]
# #### Модель классификации логистическая регрессия

# %% [markdown]
# Так как наша обучающая выборка не велика, применим параметр `solver='liblinear'`.
# Определим лучшую модель в зависимости от гиперпараметров `penalty` и `C` перебором в цикле и оценке по валидационной выборке на F1-мере.

# %%
best_model_logistic = None
best_score_f1_logistic = 0

for penalty in ('l1', 'l2'):
    for inv_reg in tqdm(range(1, 10000, 20)):
        model = LogisticRegression(penalty=penalty, solver='liblinear', C=inv_reg/100, random_state=RANDOM)
        model.fit(features_train, target_train)
        predicted_valid = model.predict(features_valid)
        score = f1_score(target_valid, predicted_valid)
        if score > best_score_f1_logistic:
            best_model_logistic = model
            best_score_f1_logistic = score    

print(f'Лучшая модель логистической регрессии: {best_model_logistic}\n'
      f'F1-мера: {best_score_f1_logistic}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_logistic.predict_proba(features_valid)[:,1])}')
# Out:
# ...
# 100%|██████████| 500/500 [01:40<00:00,  5.00it/s]
# Лучшая модель логистической регрессии: LogisticRegression(C=1.41, penalty='l1', random_state=1111, solver='liblinear')
# F1-мера: 0.25306122448979596
# AUC-ROC: 0.7772601366895352

# %% [markdown]
# При дисбалансе признаков лучший результат на F1-мере (0.56) показала модель решающего дерева.
#
# AUC-ROC мера для всех моделей значительно выше F1-меры.

# %% [raw]
# #### Определение лучшей модели по тестовой выборке
# Сравним результаты предсказаний для лучших моделей на тестовой выборке и выберем модель с лучшим значением F1-меры, при дисбалансе признаков.

# %% [raw]
# for model in [best_model_tree, best_model_forest, best_model_logistic]:
#     predicted_test = model.predict(features_test)
#     print(f'Модель {model}:\n F1-мера: {f1_score(target_test, predicted_test)}\n'
#           f'AUC-ROC: {roc_auc_score(target_test, model.predict_proba(features_test)[:,1])}\n'
#           f'Матрица ошибок:\n {confusion_matrix(target_test, predicted_test)}\n{"-"*50}')

# %% [markdown]
# <div class='alert alert-danger'>❌По тестовой выборке сравнивать нельзя, для этого есть валидационная. Тестовая используется только для финального тестирования лучше модели.
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Спасибо за замечание. Прошу обратить внимание, что в данном разделе, не происходит знакомство моделей с тестовыми данными, тоесть не происходит обучения на тестовой выборке (метод fit).
# <br> Валидационная выборка применялась, для подбора гипперпараметров, лучшая модель на валидационной выборке была определена ранее.
# <br> Решил перевести данную ячейку в формат без обработки.
#
# </div>

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# ### Пример борьбы с дисбалансом классов, при помощи параметра модели

# %% [markdown]
# Применим для моделей параметр class_weight='balanced'.

# %% [markdown]
# #### Модель классификации деревом решений

# %% [markdown]
# Определим лучшую модель в зависимости от гиперпараметра `max_depth` перебором в цикле и оценке по валидационной выборке на F1-мере.

# %%
best_model_tree_balanced = None
best_score_f1_tree_balanced = 0

for depth in tqdm(range(1, 11)):
    model = DecisionTreeClassifier(class_weight='balanced', random_state=RANDOM, max_depth=depth)
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    score = f1_score(target_valid, predicted_valid)
    if score > best_score_f1_tree_balanced:
        best_model_tree_balanced = model
        best_score_f1_tree_balanced = score

print(f'Лучшая модель решающего дерева: {best_model_tree_balanced}\n'
      f'F1-мера: {best_score_f1_tree_balanced}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_tree_balanced.predict_proba(features_valid)[:,1])}')
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 31.84it/s]
# Лучшая модель решающего дерева: DecisionTreeClassifier(class_weight='balanced', max_depth=8, random_state=1111)
# F1-мера: 0.5679012345679012
# AUC-ROC: 0.7939421090573117

# %% [markdown]
# #### Модель классификации случайный лес

# %% [markdown]
# Определим лучшую модель в зависимости от гиперпараметра `n_estimators` перебором в цикле и оценке по валидационной выборке на F1-мере, параметр `max_depth` примем равным 8, как оптимальный для решающего дерева.

# %%
best_model_forest_balanced = None
best_score_f1_forest_balanced = 0

for est in tqdm(range(1, 100, 2)):
    model = RandomForestClassifier(class_weight='balanced', random_state=RANDOM, n_estimators=est, max_depth=8)
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    score = f1_score(target_valid, predicted_valid)
    if score > best_score_f1_forest_balanced:
        best_model_forest_balanced = model
        best_score_f1_forest_balanced = score

print(f'Лучшая модель случайного леса: {best_model_forest_balanced}\n'
      f'F1-мера: {best_score_f1_forest_balanced}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_forest_balanced.predict_proba(features_valid)[:,1])}')
# Out:
# 100%|██████████| 50/50 [00:17<00:00,  2.79it/s]
# Лучшая модель случайного леса: RandomForestClassifier(class_weight='balanced', max_depth=8, n_estimators=77,
#                        random_state=1111)
# F1-мера: 0.6206896551724137
# AUC-ROC: 0.8582754169328866

# %% [markdown]
# #### Модель классификации логистическая регрессия

# %% [markdown]
# Так как наша обучающая выборка не велика, применим параметр `solver='liblinear'`.
# Определим лучшую модель в зависимости от гиперпараметров `penalty` и `C` перебором в цикле и оценке по валидационной выборке на F1-мере.

# %%
best_model_logistic_balanced = None
best_score_f1_logistic_balanced = 0

for penalty in ('l1', 'l2'):
    for inv_reg in tqdm(range(1, 10000, 20)):
        model = LogisticRegression(penalty=penalty, solver='liblinear', C=inv_reg/100, class_weight='balanced', random_state=RANDOM)
        model.fit(features_train, target_train)
        predicted_valid = model.predict(features_valid)
        score = f1_score(target_valid, predicted_valid)
        if score > best_score_f1_logistic_balanced:
            best_model_logistic_balanced = model
            best_score_f1_logistic_balanced = score    

print(f'Лучшая модель логистической регрессии: {best_model_logistic_balanced}\n'
      f'F1-мера: {best_score_f1_logistic_balanced}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_logistic_balanced.predict_proba(features_valid)[:,1])}')
# Out:
# ...
# 100%|██████████| 500/500 [01:39<00:00,  5.00it/s]
# Лучшая модель логистической регрессии: LogisticRegression(C=0.61, class_weight='balanced', penalty='l1',
#                    random_state=1111, solver='liblinear')
# F1-мера: 0.5112781954887218
# AUC-ROC: 0.7788639754711393

# %% [markdown]
# ### Устранение дисбаланса в данных

# %% [markdown]
# Создадим функцию `upsample` для устранения дисбаланса.
#
# На вход она будет получать две выборки: признаки и целевой признак, а также множитель повторений для "единичного" класса.
#
# Возвращать она будет сбалансированные выборки: признаки и целевой признак.

# %%
def upsample(features, target, repeat):
    
    # выделение выборок согласно класса "0" или "1"
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    # увеличение размера выборок за счёт "1" класса и множителя "repeat"
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    # перемешивание выборок
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

# %% [markdown]
# Применим функцию `upsample` к обучающей и валидационной выборкам, коэффициент `repeat` примем равным 4, так как доля класса "1" состявляет 0.2 (тем самым размеры классов станут равными).

# %% [markdown]
# <div class='alert alert-success'> ✔️Рабочая функция, хорошо, что не забыли перемешать данные.
# </div>

# %%
# выравнивание обучающих признаков
features_train_balanced, target_train_balanced = upsample(features_train, target_train, 4)

# выравнивание валидационных признаков - применение показало худшее качество, закоментировал код
#features_valid, target_valid = upsample(features_valid, target_valid, 4)

# %% [markdown]
# ### Стандартизация данных
# Стандартизация данных не привела к улучшению показателя F1-меры. Ячейка переведена в формат без обработки.

# %%
scaler = StandardScaler()
scaler.fit(features_train_balanced)

features_train_balanced_stand_scaler= scaler.transform(features_train_balanced)
features_valid_stand_scaler = scaler.transform(features_valid)
features_test_stand_scaler = scaler.transform(features_test)

# %% [markdown]
# <div class='alert alert-danger'>❌Хорошо, что при шкалировании признаков не забыл, что fit нужно делать только на train выборке. Стандартизация должна была повлиять на результаты логистической регресии, для деревьев она бесполезна, ты проверил?
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Спасибо за замечание.
# <br> Без стандартизации данных на логистической регрессии:
# F1-мера: 0.5121042830540038
# AUC-ROC: 0.7787615235164491
# <br> При стандартизации данных на логистической регрессии:
# F1-мера: 0.5143918291550604
# AUC-ROC: 0.7786553460361338
# <br> F1-мера выросла, но незначительно.
# </div>

# %% [markdown]
# ### Получение оптимальной модели при устранённом дисбалансе классов

# %% [markdown]
# #### Модель классификации деревом решений

# %% [markdown]
# Определим лучшую модель в зависимости от гиперпараметра `max_depth` перебором в цикле и оценке по валидационной выборке на F1-мере.

# %%
best_model_tree = None
best_score_f1_tree = 0

for depth in tqdm(range(1, 11)):
    model = DecisionTreeClassifier(random_state=RANDOM, max_depth=depth)
    model.fit(features_train_balanced_stand_scaler, target_train_balanced)
    predicted_valid = model.predict(features_valid_stand_scaler)
    score = f1_score(target_valid, predicted_valid)
    if score > best_score_f1_tree:
        best_model_tree = model
        best_score_f1_tree = score

print(f'Лучшая модель решающего дерева: {best_model_tree}\n'
      f'F1-мера: {best_score_f1_tree}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_tree.predict_proba(features_valid_stand_scaler)[:,1])}')
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 35.61it/s]
# Лучшая модель решающего дерева: DecisionTreeClassifier(max_depth=9, random_state=1111)
# F1-мера: 0.5695067264573992
# AUC-ROC: 0.7820381233037217

# %% [markdown]
# #### Модель классификации случайный лес

# %% [markdown]
# Определим лучшую модель в зависимости от гиперпараметра `n_estimators` перебором в цикле и оценке по валидационной выборке на F1-мере, параметр `max_depth` примем равным 9, как оптимальный для решающего дерева.

# %%
best_model_forest = None
best_score_f1_forest = 0

for est in tqdm(range(1, 100, 2)):
    model = RandomForestClassifier(random_state=RANDOM, n_estimators=est, max_depth=9)
    model.fit(features_train_balanced_stand_scaler, target_train_balanced)
    predicted_valid = model.predict(features_valid_stand_scaler)
    score = f1_score(target_valid, predicted_valid)
    if score > best_score_f1_forest:
        best_model_forest = model
        best_score_f1_forest = score

print(f'Лучшая модель случайного леса: {best_model_forest}\n'
      f'F1-мера: {best_score_f1_forest}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_forest.predict_proba(features_valid_stand_scaler)[:,1])}')
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.85it/s]
# Лучшая модель случайного леса: RandomForestClassifier(max_depth=9, n_estimators=37, random_state=1111)
# F1-мера: 0.6252821670428894
# AUC-ROC: 0.8558817667187618

# %% [markdown]
# #### Модель классификации логистическая регрессия

# %% [markdown]
# Так как наша обучающая выборка не велика, применим параметр `solver='liblinear'`.
# Определим лучшую модель в зависимости от гиперпараметров `penalty` и `C` перебором в цикле и оценке по валидационной выборке на F1-мере.

# %%
best_model_logistic = None
best_score_f1_logistic = 0

for penalty in ('l1', 'l2'):
    for inv_reg in tqdm(range(1, 10000, 20)):
        model = LogisticRegression(penalty=penalty, solver='liblinear', C=inv_reg/100, random_state=RANDOM)
        model.fit(features_train_balanced_stand_scaler, target_train_balanced)
        predicted_valid = model.predict(features_valid_stand_scaler)
        score = f1_score(target_valid, predicted_valid)
        if score > best_score_f1_logistic:
            best_model_logistic = model
            best_score_f1_logistic = score    

print(f'Лучшая модель логистической регрессии: {best_model_logistic}\n'
      f'F1-мера: {best_score_f1_logistic}\n'
      f'AUC-ROC: {roc_auc_score(target_valid, best_model_logistic.predict_proba(features_valid_stand_scaler)[:,1])}')
# Out:
# ...
# 100%|██████████| 500/500 [01:38<00:00,  5.07it/s]
# Лучшая модель логистической регрессии: LogisticRegression(C=0.01, random_state=1111, solver='liblinear')
# F1-мера: 0.5143918291550604
# AUC-ROC: 0.7786553460361338

# %% [markdown]
# При отсутствии дисбаланса признаков лучший результат на F1-мере (0.625 на валидационной выборке) показала модель случайного леса.
#
# AUC-ROC мера для всех моделей значительно выше F1-меры.

# %% [raw]
# #### Определение лучшей модели по тестовой выборке
# Сравним результаты предсказаний для лучших моделей на тестовой выборке и выберем модель с лучшим значением F1-меры, при отсутствии дисбаланса признаков.

# %% [raw]
# for model in [best_model_tree, best_model_forest, best_model_logistic]:
#     predicted_test = model.predict(features_test)
#     print(f'Модель {model}:\n F1-мера: {f1_score(target_test, predicted_test)}\n'
#           f'AUC-ROC: {roc_auc_score(target_test, model.predict_proba(features_test)[:,1])}\n'
#           f'Матрица ошибок:\n {confusion_matrix(target_test, predicted_test)}\n{"-"*50}')

# %% [markdown]
# <div class='alert alert-danger'>❌Тот же комментарий в отношении тест выборки. У тебя уже есть результаты валидации и можно использовать их.
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Спасибо за замечание.
# <br> Решил перевести данную ячейку в формат без обработки.
#
# </div>

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Лучший результат на F1-мере (0.625 на валидационной выборке) показала модель случайного леса, произведём её дообучение на объединённой выборке и итоговое тестирование.

# %% [markdown]
# ### Дообучение лучших моделей по объединённой обучающей и валидационной выборкам.

# %%
# Объединение обучающей и валидационной выборок
features_train_balanced_stand_scaler = np.concatenate((features_train_balanced_stand_scaler, features_valid_stand_scaler), axis=0)
target_train_balanced = pd.concat([target_train_balanced, target_valid])
# Дообучение моделей
best_model_forest.fit(features_train_balanced_stand_scaler, target_train_balanced)
print(best_model_forest)
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=37, random_state=1111)

# %% [markdown]
# <div class='alert alert-success'> ✔️Отлично, что не забыл объединить весь набор для обучения! Все дельнейшие манипуляции можно было производить только с одним выбранным алгоритмом.
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Сделал итоговое тестирование только для лучшей модели полученной на валидационной выборке.
#
# </div>

# %% [markdown]
# ### Итоговое тестирование лучшей модели

# %% [markdown]
# Лучшее значение на F1-мере на валидационной выборке показала модель случайный лес на предварительно сбалансированных данных. Проведём проверку лучшей модели на тестовой выборке.

# %%
predicted_test = best_model_forest.predict(features_test_stand_scaler)
print(f'Модель {best_model_forest}:\n F1-мера: {f1_score(target_test, predicted_test)}\n'
      f'AUC-ROC: {roc_auc_score(target_test, best_model_forest.predict_proba(features_test_stand_scaler)[:,1])}\n'
      f'Матрица ошибок:\n {confusion_matrix(target_test, predicted_test)}')
fpr, tpr, thresholds = roc_curve(target_test, best_model_forest.predict_proba(features_test_stand_scaler)[:,1])
plt.plot(fpr, tpr, color="darkorange")
plt.plot([0, 1], [0, 1], color="navy", linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f'Кривая ошибок')
plt.show()
# Out:
# Модель RandomForestClassifier(max_depth=9, n_estimators=37, random_state=1111):
#  F1-мера: 0.6230677764565994
# AUC-ROC: 0.8766632291402958
# Матрица ошибок:
#  [[1240  208]
#  [ 109  262]]

# %% [markdown]
# **Значение F1-меры лучшей итоговой модели случайный лес составило 0.623, что удовлетворяет поставленной задаче (0.59).**

# %% [markdown]
# <div class='alert alert-danger'>❌Хорошие визуализации и корректный код. Однако тут нужна только финальная оценка одной модели, как писал, без сравнения.
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Оставил оценку лучшей модели, остальные модели убрал.
#
# </div>

# %% [markdown]
# <div class='alert alert-danger'>❌Также давай рассмотрим еще один способ борьбы с дисбалансом.
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Выполнил решение борьбы с дисбалансом классов, при помощи гиперпараметра модели в пункте 3.1.
#
# </div>

# %% [markdown]
# <div class='alert alert-info'>🏁 Хорошая работа! Проведена предобработка данных, корректное разделение на выборки, применено несколько алгоритмов. Осталось рассмотреть еще один способ борьбы с дисбалансом, разобраться с использованием тестовой выборки и дать обратную связь по выделенным ячейкам.
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> Комментарий, Таширева.
# <br> Спасибо за советы, они позволили поднять качество итоговой модели. И дали доплнительные знания.
#
# </div>
